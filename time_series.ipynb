# %%
import pypsa
n = pypsa.Network('results/networks/20_02_2023_elec_s_117_ec_lcopt_Co2L-3H-CCL-onwind+p0.3.nc')
# Out:
# INFO:pypsa.io:Imported network 20_02_2023_elec_s_117_ec_lcopt_Co2L-3H-CCL-onwind+p0.3.nc has buses, carriers, generators, global_constraints, lines, links, loads, stores

# %%
n.generators_t.p_max_pu.loc["2013-07":"2013-09", 'off_NL_10 offwind-dc'].plot(figsize=(15,3))
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame(
    {attr: n.stores_t[attr]["NL1 0 battery"].loc["2013-07-01"]  for attr in ["p", "e"]}
)
df.plot(grid=True, figsize=(10, 5))
plt.legend(labels=["Energy output", "State of charge"])
plt.tight_layout()
